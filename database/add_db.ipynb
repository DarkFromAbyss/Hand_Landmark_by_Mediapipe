# %%
import os
import sqlite3
import kagglehub
import pandas as pd

# %%
path = kagglehub.dataset_download("tawfikelmetwally/employee-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 18.5k/18.5k [00:00<00:00, 5.73MB/s]
# Extracting files...
# Path to dataset files: C:\Users\PC\.cache\kagglehub\datasets\tawfikelmetwally\employee-dataset\versions\1

# %%
df = pd.read_csv(path+"/Employee.csv")

# %%
df.head(5)
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
df.dropna()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
def fun(text):
    if text == 'Male': 
        return 0
    elif text == 'Female': 
        return 1
    else: 
        return 2
    
df['Gender'] = df.apply(fun)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11392\3989466674.py in ?()
# ----> 9 def fun(text):
#      10     if text == "Male":
#      11         return 0
#      12     elif text == "Female":
#
# c:\Users\PC\Deskop\Hand_Landmark_by_Mediapipe\myenv\lib\site-packages\pandas\core\frame.py in ?(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10377             engine_kwargs=engine_kwargs,
#   10378             args=args,
#   10379             kwargs=kwargs,
#   10380         )
# > 10381         return op.apply().__finalize__(self, method="apply")
#
# c:\Users\PC\Deskop\Hand_Landmark_by_Mediapipe\myenv\lib\site-packages\pandas\core\apply.py in ?(self)
#     912         # raw
#     913         elif self.raw:
#     914             return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# ...

# %%
ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
ROOT
# Out:
# 'c:\\Users\\PC\\Deskop\\Hand_Landmark_by_Mediapipe'

# %%
DATABASE_PATH = os.path.join(ROOT, "database/hands.db")
conn = sqlite3.connect(DATABASE_PATH) 
cursor = conn.cursor()

# %%
cursor.execute('''
                CREATE TABLE test (
                                    Education NVARCHAR(50), 
                                    JoiningYear YEAR, 
                                    City NVARCHAR(50), 
                                    PaymentTier INTERGER, 
                                    AGE INTERGER, 
                                    Gender BOOL,
                                    EverBenched BOOL,
                                    ExperienceInCurrentDomain INTERGER, 
                                    LeaveOrNot BOOL)
                                    ; ''')
conn.commit()

# %%
cursor.close()
